# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
x=np.array([10,20,30,40,50,60])
y=np.array([15,45,50,70,110,130])
x
# Out:
# array([10, 20, 30, 40, 50, 60])

# %%
linreg=LinearRegression()

# %%
linreg
# Out:
# LinearRegression()

# %%
X=x.reshape(-1,1)
X
# Out:
# array([[10],
#        [20],
#        [30],
#        [40],
#        [50],
#        [60]])

# %%
linreg.fit(X,y)
# Out:
# LinearRegression()

# %%
y_predict=linreg.predict(X)

# %%
plt.scatter(X,y)
plt.plot(X,y_predict,'Red')
plt.show()

# %%
# 斜率：SUM[(X-X的平均)^2]/[SUM(X-X的平均)*(y-y的平均)]
print(linreg.coef_)
# Out:
# [2.25714286]

# %%
# 線性回歸 y=斜率*X+b

# b：從外軸的切入點
print(linreg.intercept_)

# => 公式： y=2.5714286X-9
# Out:
# -9.0

# %% [markdown]
# # 多元線性回歸

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset=pd.read_csv('Lesson13-50_Startups.csv')

# %%
dataset
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59        443898.53  California  191792.06
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York  182901.99
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90        99814.71        362861.36    New York  156991.12
# 6   134615.46       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida  155752.60
# 8   120542.52       148718.95        311613.29    New York  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California  144259.40
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07        252664.93  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15  114523.61       122616.84        261776.23    New York  129917.04
# 16   78013.11       121597.55        264346.06  California  126992.93
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York  122776.86
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida  110352.25
# 23   67532.53       105751.03        304768.73     Florida  108733.99
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25   64664.71       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York  105008.31
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48       153032.06        107138.38    New York  101004.64
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York   97483.56
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49        214634.81     Florida   96778.92
# 34   46426.07       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York   96479.51
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51        82982.09        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67  California   78239.91
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42   23640.93        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California   65200.33
# 45    1000.23       124153.04          1903.93    New York   64926.08
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00    New York   35673.41
# 49       0.00       116983.80         45173.06  California   14681.40

# %%
# 拆表格
X=dataset.iloc[:,0:4] #所有欄,0~3列

# %%
X
# Out:
#     R&D Spend  Administration  Marketing Spend       State
# 0   165349.20       136897.80        471784.10    New York
# 1   162597.70       151377.59        443898.53  California
# 2   153441.51       101145.55        407934.54     Florida
# 3   144372.41       118671.85        383199.62    New York
# 4   142107.34        91391.77        366168.42     Florida
# 5   131876.90        99814.71        362861.36    New York
# 6   134615.46       147198.87        127716.82  California
# 7   130298.13       145530.06        323876.68     Florida
# 8   120542.52       148718.95        311613.29    New York
# 9   123334.88       108679.17        304981.62  California
# 10  101913.08       110594.11        229160.95     Florida
# 11  100671.96        91790.61        249744.55  California
# 12   93863.75       127320.38        249839.44     Florida
# 13   91992.39       135495.07        252664.93  California
# 14  119943.24       156547.42        256512.92     Florida
# 15  114523.61       122616.84        261776.23    New York
# 16   78013.11       121597.55        264346.06  California
# 17   94657.16       145077.58        282574.31    New York
# 18   91749.16       114175.79        294919.57     Florida
# 19   86419.70       153514.11             0.00    New York
# 20   76253.86       113867.30        298664.47  California
# 21   78389.47       153773.43        299737.29    New York
# 22   73994.56       122782.75        303319.26     Florida
# 23   67532.53       105751.03        304768.73     Florida
# 24   77044.01        99281.34        140574.81    New York
# 25   64664.71       139553.16        137962.62  California
# 26   75328.87       144135.98        134050.07     Florida
# 27   72107.60       127864.55        353183.81    New York
# 28   66051.52       182645.56        118148.20     Florida
# 29   65605.48       153032.06        107138.38    New York
# 30   61994.48       115641.28         91131.24     Florida
# 31   61136.38       152701.92         88218.23    New York
# 32   63408.86       129219.61         46085.25  California
# 33   55493.95       103057.49        214634.81     Florida
# 34   46426.07       157693.92        210797.67  California
# 35   46014.02        85047.44        205517.64    New York
# 36   28663.76       127056.21        201126.82     Florida
# 37   44069.95        51283.14        197029.42  California
# 38   20229.59        65947.93        185265.10    New York
# 39   38558.51        82982.09        174999.30  California
# 40   28754.33       118546.05        172795.67  California
# 41   27892.92        84710.77        164470.71     Florida
# 42   23640.93        96189.63        148001.11  California
# 43   15505.73       127382.30         35534.17    New York
# 44   22177.74       154806.14         28334.72  California
# 45    1000.23       124153.04          1903.93    New York
# 46    1315.46       115816.21        297114.46     Florida
# 47       0.00       135426.92             0.00  California
# 48     542.05        51743.15             0.00    New York
# 49       0.00       116983.80         45173.06  California

# %%
X["State"].unique()
# Out:
# array(['New York', 'California', 'Florida'], dtype=object)

# %%
y=dataset.iloc[:,4]

# %%
y
# Out:
# 0     192261.83
# 1     191792.06
# 2     191050.39
# 3     182901.99
# 4     166187.94
# 5     156991.12
# 6     156122.51
# 7     155752.60
# 8     152211.77
# 9     149759.96
# 10    146121.95
# 11    144259.40
# 12    141585.52
# 13    134307.35
# 14    132602.65
# 15    129917.04
# 16    126992.93
# 17    125370.37
# 18    124266.90
# 19    122776.86
# 20    118474.03
# 21    111313.02
# 22    110352.25
# 23    108733.99
# 24    108552.04
# 25    107404.34
# 26    105733.54
# 27    105008.31
# 28    103282.38
# 29    101004.64
# 30     99937.59
# 31     97483.56
# 32     97427.84
# 33     96778.92
# 34     96712.80
# 35     96479.51
# 36     90708.19
# 37     89949.14
# 38     81229.06
# 39     81005.76
# 40     78239.91
# 41     77798.83
# 42     71498.49
# 43     69758.98
# 44     65200.33
# 45     64926.08
# 46     49490.75
# 47     42559.73
# 48     35673.41
# 49     14681.40
# Name: Profit, dtype: float64

# %%
pd.get_dummies(X['State'])
# state裡有3個類別，讓點點只標示在其中一個
# Out:
#     California  Florida  New York
# 0        False    False      True
# 1         True    False     False
# 2        False     True     False
# 3        False    False      True
# 4        False     True     False
# 5        False    False      True
# 6         True    False     False
# 7        False     True     False
# 8        False    False      True
# 9         True    False     False
# 10       False     True     False
# 11        True    False     False
# 12       False     True     False
# 13        True    False     False
# 14       False     True     False
# 15       False    False      True
# 16        True    False     False
# 17       False    False      True
# 18       False     True     False
# 19       False    False      True
# 20        True    False     False
# 21       False    False      True
# 22       False     True     False
# 23       False     True     False
# 24       False    False      True
# 25        True    False     False
# 26       False     True     False
# 27       False    False      True
# 28       False     True     False
# 29       False    False      True
# 30       False     True     False
# 31       False    False      True
# 32        True    False     False
# 33       False     True     False
# 34        True    False     False
# 35       False    False      True
# 36       False     True     False
# 37        True    False     False
# 38       False    False      True
# 39        True    False     False
# 40        True    False     False
# 41       False     True     False
# 42        True    False     False
# 43       False    False      True
# 44        True    False     False
# 45       False    False      True
# 46       False     True     False
# 47        True    False     False
# 48       False    False      True
# 49        True    False     False

# %%
pd.get_dummies(X['State'],drop_first=True)
# Out:
#     Florida  New York
# 0     False      True
# 1     False     False
# 2      True     False
# 3     False      True
# 4      True     False
# 5     False      True
# 6     False     False
# 7      True     False
# 8     False      True
# 9     False     False
# 10     True     False
# 11    False     False
# 12     True     False
# 13    False     False
# 14     True     False
# 15    False      True
# 16    False     False
# 17    False      True
# 18     True     False
# 19    False      True
# 20    False     False
# 21    False      True
# 22     True     False
# 23     True     False
# 24    False      True
# 25    False     False
# 26     True     False
# 27    False      True
# 28     True     False
# 29    False      True
# 30     True     False
# 31    False      True
# 32    False     False
# 33     True     False
# 34    False     False
# 35    False      True
# 36     True     False
# 37    False     False
# 38    False      True
# 39    False     False
# 40    False     False
# 41     True     False
# 42    False     False
# 43    False      True
# 44    False     False
# 45    False      True
# 46     True     False
# 47    False     False
# 48    False      True
# 49    False     False

# %% [markdown]
# ## 把數據分割成訓練集&測試集

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)
# test_size=0.3 = 隨意抓取30%測試集
# random_state 重跑訓練值幾遍

# %%
X_train
# Out:
#     R&D Spend  Administration  Marketing Spend       State
# 7   130298.13       145530.06        323876.68     Florida
# 14  119943.24       156547.42        256512.92     Florida
# 45    1000.23       124153.04          1903.93    New York
# 48     542.05        51743.15             0.00    New York
# 29   65605.48       153032.06        107138.38    New York
# 15  114523.61       122616.84        261776.23    New York
# 30   61994.48       115641.28         91131.24     Florida
# 32   63408.86       129219.61         46085.25  California
# 16   78013.11       121597.55        264346.06  California
# 42   23640.93        96189.63        148001.11  California
# 20   76253.86       113867.30        298664.47  California
# 43   15505.73       127382.30         35534.17    New York
# 8   120542.52       148718.95        311613.29    New York
# 13   91992.39       135495.07        252664.93  California
# 25   64664.71       139553.16        137962.62  California
# 5   131876.90        99814.71        362861.36    New York
# 17   94657.16       145077.58        282574.31    New York
# 40   28754.33       118546.05        172795.67  California
# 49       0.00       116983.80         45173.06  California
# 1   162597.70       151377.59        443898.53  California
# 12   93863.75       127320.38        249839.44     Florida
# 37   44069.95        51283.14        197029.42  California
# 24   77044.01        99281.34        140574.81    New York
# 6   134615.46       147198.87        127716.82  California
# 23   67532.53       105751.03        304768.73     Florida
# 36   28663.76       127056.21        201126.82     Florida
# 21   78389.47       153773.43        299737.29    New York
# 19   86419.70       153514.11             0.00    New York
# 9   123334.88       108679.17        304981.62  California
# 39   38558.51        82982.09        174999.30  California
# 46    1315.46       115816.21        297114.46     Florida
# 3   144372.41       118671.85        383199.62    New York
# 0   165349.20       136897.80        471784.10    New York
# 47       0.00       135426.92             0.00  California
# 44   22177.74       154806.14         28334.72  California

# %%
X_test
# Out:
#     R&D Spend  Administration  Marketing Spend       State
# 28   66051.52       182645.56        118148.20     Florida
# 11  100671.96        91790.61        249744.55  California
# 10  101913.08       110594.11        229160.95     Florida
# 41   27892.92        84710.77        164470.71     Florida
# 2   153441.51       101145.55        407934.54     Florida
# 27   72107.60       127864.55        353183.81    New York
# 38   20229.59        65947.93        185265.10    New York
# 31   61136.38       152701.92         88218.23    New York
# 22   73994.56       122782.75        303319.26     Florida
# 4   142107.34        91391.77        366168.42     Florida
# 33   55493.95       103057.49        214634.81     Florida
# 35   46014.02        85047.44        205517.64    New York
# 26   75328.87       144135.98        134050.07     Florida
# 34   46426.07       157693.92        210797.67  California
# 18   91749.16       114175.79        294919.57     Florida

# %%
# 確定筆數
print(X_train.count())
print(X_test.count())
# Out:
# R&D Spend          35
# Administration     35
# Marketing Spend    35
# State              35
# dtype: int64
# R&D Spend          15
# Administration     15
# Marketing Spend    15
# State              15
# dtype: int64

# %% [markdown]
# # 卡在這

# %%
from sklearn.linear_model import LinearRegression 
regressor=LinearRegression()# 初始化
model=regressor.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\pokemon_sleep_sp\線性回歸.ipynb 儲存格 27 line 3
#       <a href='vscode-notebook-cell:/d%3A/pokemon_sleep_sp/%E7%B7%9A%E6%80%A7%E5%9B%9E%E6%AD%B8.ipynb#X35sZmlsZQ%3D%3D?line=0'>1</a> from sklearn.linear_model import LinearRegression
#       <a href='vscode-notebook-cell:/d%3A/pokemon_sleep_sp/%E7%B7%9A%E6%80%A7%E5%9B%9E%E6%AD%B8.ipynb#X35sZmlsZQ%3D%3D?line=1'>2</a> regressor=LinearRegression()# 初始化
# ----> <a href='vscode-notebook-cell:/d%3A/pokemon_sleep_sp/%E7%B7%9A%E6%80%A7%E5%9B%9E%E6%AD%B8.ipynb#X35sZmlsZQ%3D%3D?line=2'>3</a> model=regressor.fit(X_train,y_train)
#
# File d:\pokemon_sleep_sp\.venv\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File d:\pokemon_sleep_sp\.venv\lib\site-packages\sklearn\linear_model\_base.py:678, in LinearRegression.fit(self, X, y, sample_weight)
#     674 n_jobs_ = self.n_jobs
#     676 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 678 X, y = self._validate_data(
#     679     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     680 )
#     682 has_sw = sample_weight is not None
#     683 if has_sw:
#
# File d:\pokemon_sleep_sp\.venv\lib\site-packages\sklearn\base.py:622, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     620         y = check_array(y, input_name="y", **check_y_params)
#     621     else:
# --> 622         X, y = check_X_y(X, y, **check_params)
#     623     out = X, y
#     625 if not no_val_X and check_params.get("ensure_2d", True):
#
# File d:\pokemon_sleep_sp\.venv\lib\site-packages\sklearn\utils\validation.py:1146, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#    1141         estimator_name = _check_estimator_name(estimator)
#    1142     raise ValueError(
#    1143         f"{estimator_name} requires y to be passed, but the target y is None"
#    1144     )
# -> 1146 X = check_array(
#    1147     X,
#    1148     accept_sparse=accept_sparse,
#    1149     accept_large_sparse=accept_large_sparse,
#    1150     dtype=dtype,
#    1151     order=order,
#    1152     copy=copy,
#    1153     force_all_finite=force_all_finite,
#    1154     ensure_2d=ensure_2d,
#    1155     allow_nd=allow_nd,
#    1156     ensure_min_samples=ensure_min_samples,
#    1157     ensure_min_features=ensure_min_features,
#    1158     estimator=estimator,
#    1159     input_name="X",
#    1160 )
#    1162 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric, estimator=estimator)
#    1164 check_consistent_length(X, y)
#
# File d:\pokemon_sleep_sp\.venv\lib\site-packages\sklearn\utils\validation.py:915, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     913         array = xp.astype(array, dtype, copy=False)
#     914     else:
# --> 915         array = _asarray_with_order(array, order=order, dtype=dtype, xp=xp)
#     916 except ComplexWarning as complex_warning:
#     917     raise ValueError(
#     918         "Complex data not supported\n{}\n".format(array)
#     919     ) from complex_warning
#
# File d:\pokemon_sleep_sp\.venv\lib\site-packages\sklearn\utils\_array_api.py:380, in _asarray_with_order(array, dtype, order, copy, xp)
#     378     array = numpy.array(array, order=order, dtype=dtype)
#     379 else:
# --> 380     array = numpy.asarray(array, order=order, dtype=dtype)
#     382 # At this point array is a NumPy ndarray. We convert it to an array
#     383 # container that is consistent with the input's namespace.
#     384 return xp.asarray(array)
#
# File d:\pokemon_sleep_sp\.venv\lib\site-packages\pandas\core\generic.py:2084, in NDFrame.__array__(self, dtype)
#    2082 def __array__(self, dtype: npt.DTypeLike | None = None) -> np.ndarray:
#    2083     values = self._values
# -> 2084     arr = np.asarray(values, dtype=dtype)
#    2085     if (
#    2086         astype_is_view(values.dtype, arr.dtype)
#    2087         and using_copy_on_write()
#    2088         and self._mgr.is_single_block
#    2089     ):
#    2090         # Check if both conversions can be done without a copy
#    2091         if astype_is_view(self.dtypes.iloc[0], values.dtype) and astype_is_view(
#    2092             values.dtype, arr.dtype
#    2093         ):
#
# ValueError: could not convert string to float: 'Florida'
